# %%
from utils import *
from filters import *

# %%
image = load_image("img/test.jpg", to_color=True)

# %%
show_image(image)

# %% [markdown]
# # Mean Filter

# %%
apply_mean_filter(image)

# %%
apply_mean_filter_grayscale(image)

# %% [markdown]
# # Gaussian Filter

# %%
apply_gaussian_filter(image)

# %%
apply_gaussian_filter_grayscale(image)

# %% [markdown]
# # Median Filter

# %%
apply_median_filter(image)

# %%
apply_median_filter_grayscale(image)

# %% [markdown]
# # Laplacian Filter

# %%
apply_laplacian_grayscale(image)

# %% [markdown]
# # Unsharp Filter

# %%
apply_unsharp_filter_grayscale(image)

# %% [markdown]
# # Conservative Smoothing

# %%
# conservative_smoothing(image)

# %%
# conservative_smoothing_grayscale(image)
